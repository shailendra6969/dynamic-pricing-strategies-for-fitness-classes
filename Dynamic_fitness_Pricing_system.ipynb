# %% [markdown]
# # Implement dynamic pricing strategies for fitness classes based on demand, time, and location

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df1 = pd.read_csv('Classes April-May 2018.csv')
df2 = pd.read_csv('Classes June 2018.csv')
print(df1.head())  
print(df2.head())
# Out:
#   ActivitySiteID      ActivityDescription  \
# 0            HXP  20-20-20  2.45pm-3.45pm
# 1            HXP  20-20-20  2.45pm-3.45pm
# 2            HXP  20-20-20  2.45pm-3.45pm
# 3            HXP  20-20-20  2.45pm-3.45pm
# 4            HXP  20-20-20  2.45pm-3.45pm
#
#   BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                               08-Apr-18         14:45:00          25
# 1                               15-Apr-18         14:45:00          25
# 2                               22-Apr-18         14:45:00          25
# 3                               29-Apr-18         14:45:00          25
# 4                               06-May-18         14:45:00          25
#
#    Number Booked  Price (INR)
# 0             12        499.0
# 1             15        499.0
# 2             14        499.0
# 3              9        499.0
# 4              7        499.0
#   ActivitySiteID     ActivityDescription  \
# 0            BRP  20:20:20  9.30-10.30am
# 1            BRP  20:20:20  9.30-10.30am
# 2            BRP  20:20:20  9.30-10.30am
# 3            BRP  20:20:20  9.30-10.30am
# 4            BRP  20:20:20  9.30-10.30am
#
#   BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                               01-Jun-18          9:30:00          35
# 1                               08-Jun-18          9:30:00          35
# 2                               15-Jun-18          9:30:00          35
# 3                               22-Jun-18          9:30:00          35
# 4                               29-Jun-18          9:30:00          35
#
#    Number Booked  Price (INR)
# 0             28          499
# 1             35          499
# 2             31          499
# 3             32          499
# 4             19          499

# %%
df = pd.concat([df1, df2], ignore_index=True)
df
# Out:
#      ActivitySiteID      ActivityDescription  \
# 0               HXP  20-20-20  2.45pm-3.45pm
# 1               HXP  20-20-20  2.45pm-3.45pm
# 2               HXP  20-20-20  2.45pm-3.45pm
# 3               HXP  20-20-20  2.45pm-3.45pm
# 4               HXP  20-20-20  2.45pm-3.45pm
# ...             ...                      ...
# 3284            TSC       Zumba  6.30-7.30pm
# 3285            TSC       Zumba  6.30-7.30pm
# 3286            TSC            Zumba - 6-7pm
# 3287            TSC            Zumba - 6-7pm
# 3288            TSC            Zumba - 6-7pm
#
#      BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                                  08-Apr-18         14:45:00          25
# 1                                  15-Apr-18         14:45:00          25
# 2                                  22-Apr-18         14:45:00          25
# 3                                  29-Apr-18         14:45:00          25
# 4                                  06-May-18         14:45:00          25
# ...                                      ...              ...         ...
# 3284                               18-Jun-18         18:30:00          18
# 3285                               25-Jun-18         18:30:00          18
# 3286                               07-Jun-18         18:00:00          50
# 3287                               14-Jun-18         18:00:00          50
# 3288                               21-Jun-18         18:00:00          50
#
#       Number Booked  Price (INR)
# 0                12        499.0
# 1                15        499.0
# 2                14        499.0
# 3                 9        499.0
# 4                 7        499.0
# ...             ...          ...
# 3284              9       1299.0
# 3285              9       1299.0
# 3286             16       1299.0
# 3287             13       1299.0
# 3288             12       1299.0
#
# [3289 rows x 7 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#      ActivitySiteID      ActivityDescription  \
# 0               HXP  20-20-20  2.45pm-3.45pm
# 1               HXP  20-20-20  2.45pm-3.45pm
# 2               HXP  20-20-20  2.45pm-3.45pm
# 3               HXP  20-20-20  2.45pm-3.45pm
# 4               HXP  20-20-20  2.45pm-3.45pm
# ...             ...                      ...
# 3284            TSC       Zumba  6.30-7.30pm
# 3285            TSC       Zumba  6.30-7.30pm
# 3286            TSC            Zumba - 6-7pm
# 3287            TSC            Zumba - 6-7pm
# 3288            TSC            Zumba - 6-7pm
#
#      BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                                  08-Apr-18         14:45:00          25
# 1                                  15-Apr-18         14:45:00          25
# 2                                  22-Apr-18         14:45:00          25
# 3                                  29-Apr-18         14:45:00          25
# 4                                  06-May-18         14:45:00          25
# ...                                      ...              ...         ...
# 3284                               18-Jun-18         18:30:00          18
# 3285                               25-Jun-18         18:30:00          18
# 3286                               07-Jun-18         18:00:00          50
# 3287                               14-Jun-18         18:00:00          50
# 3288                               21-Jun-18         18:00:00          50
#
#       Number Booked  Price (INR)
# 0                12        499.0
# 1                15        499.0
# 2                14        499.0
# 3                 9        499.0
# 4                 7        499.0
# ...             ...          ...
# 3284              9       1299.0
# 3285              9       1299.0
# 3286             16       1299.0
# 3287             13       1299.0
# 3288             12       1299.0
#
# [3289 rows x 7 columns]

# %%
df = df.dropna()
df
# Out:
#      ActivitySiteID      ActivityDescription  \
# 0               HXP  20-20-20  2.45pm-3.45pm
# 1               HXP  20-20-20  2.45pm-3.45pm
# 2               HXP  20-20-20  2.45pm-3.45pm
# 3               HXP  20-20-20  2.45pm-3.45pm
# 4               HXP  20-20-20  2.45pm-3.45pm
# ...             ...                      ...
# 3284            TSC       Zumba  6.30-7.30pm
# 3285            TSC       Zumba  6.30-7.30pm
# 3286            TSC            Zumba - 6-7pm
# 3287            TSC            Zumba - 6-7pm
# 3288            TSC            Zumba - 6-7pm
#
#      BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                                  08-Apr-18         14:45:00          25
# 1                                  15-Apr-18         14:45:00          25
# 2                                  22-Apr-18         14:45:00          25
# 3                                  29-Apr-18         14:45:00          25
# 4                                  06-May-18         14:45:00          25
# ...                                      ...              ...         ...
# 3284                               18-Jun-18         18:30:00          18
# 3285                               25-Jun-18         18:30:00          18
# 3286                               07-Jun-18         18:00:00          50
# 3287                               14-Jun-18         18:00:00          50
# 3288                               21-Jun-18         18:00:00          50
#
#       Number Booked  Price (INR)
# 0                12        499.0
# 1                15        499.0
# 2                14        499.0
# 3                 9        499.0
# 4                 7        499.0
# ...             ...          ...
# 3284              9       1299.0
# 3285              9       1299.0
# 3286             16       1299.0
# 3287             13       1299.0
# 3288             12       1299.0
#
# [3271 rows x 7 columns]

# %%
print(df.columns.tolist())
# Out:
# ['ActivitySiteID', 'ActivityDescription', 'BookingEndDateTime (Month / Day / Year)', 'BookingStartTime', 'MaxBookees', 'Number Booked', 'Price (INR)']

# %%
if 'BookingEndDateTime (Month / Day / Year)' in df.columns:
    df.loc[:, 'BookingEndDateTime'] = pd.to_datetime(
        df['BookingEndDateTime (Month / Day / Year)'],
        format='%m/%d/%Y %H:%M:%S',  # adjust as needed
        errors='coerce'
    )
    df.drop(columns=['BookingEndDateTime (Month / Day / Year)'], inplace=True)
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\328714519.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'BookingEndDateTime'] = pd.to_datetime(
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\328714519.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['BookingEndDateTime (Month / Day / Year)'], inplace=True)
#      ActivitySiteID      ActivityDescription BookingStartTime  MaxBookees  \
# 0               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 1               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 2               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 3               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 4               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# ...             ...                      ...              ...         ...
# 3284            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3285            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3286            TSC            Zumba - 6-7pm         18:00:00          50
# 3287            TSC            Zumba - 6-7pm         18:00:00          50
# 3288            TSC            Zumba - 6-7pm         18:00:00          50
#
#       Number Booked  Price (INR) BookingEndDateTime
# 0                12        499.0                NaT
# 1                15        499.0                NaT
# 2                14        499.0                NaT
# 3                 9        499.0                NaT
# 4                 7        499.0                NaT
# ...             ...          ...                ...
# 3284              9       1299.0                NaT
# 3285              9       1299.0                NaT
# 3286             16       1299.0                NaT
# 3287             13       1299.0                NaT
# 3288             12       1299.0                NaT
#
# [3271 rows x 7 columns]

# %%
df['MaxBookees'] = pd.to_numeric(df['MaxBookees'], errors='coerce')
df['Number Booked'] = pd.to_numeric(df['Number Booked'], errors='coerce')
df['Price (INR)'] = pd.to_numeric(df['Price (INR)'], errors='coerce')
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\825929307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MaxBookees'] = pd.to_numeric(df['MaxBookees'], errors='coerce')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\825929307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number Booked'] = pd.to_numeric(df['Number Booked'], errors='coerce')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\825929307.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price (INR)'] = pd.to_numeric(df['Price (INR)'], errors='coerce')
#      ActivitySiteID      ActivityDescription BookingStartTime  MaxBookees  \
# 0               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 1               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 2               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 3               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 4               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# ...             ...                      ...              ...         ...
# 3284            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3285            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3286            TSC            Zumba - 6-7pm         18:00:00          50
# 3287            TSC            Zumba - 6-7pm         18:00:00          50
# 3288            TSC            Zumba - 6-7pm         18:00:00          50
#
#       Number Booked  Price (INR) BookingEndDateTime
# 0                12        499.0                NaT
# 1                15        499.0                NaT
# 2                14        499.0                NaT
# 3                 9        499.0                NaT
# 4                 7        499.0                NaT
# ...             ...          ...                ...
# 3284              9       1299.0                NaT
# 3285              9       1299.0                NaT
# 3286             16       1299.0                NaT
# 3287             13       1299.0                NaT
# 3288             12       1299.0                NaT
#
# [3271 rows x 7 columns]

# %%
df['BookingStartTime'] = pd.to_datetime(df['BookingStartTime'], errors='coerce').dt.time
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\1490770119.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['BookingStartTime'] = pd.to_datetime(df['BookingStartTime'], errors='coerce').dt.time
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\1490770119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BookingStartTime'] = pd.to_datetime(df['BookingStartTime'], errors='coerce').dt.time
#      ActivitySiteID      ActivityDescription BookingStartTime  MaxBookees  \
# 0               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 1               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 2               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 3               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 4               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# ...             ...                      ...              ...         ...
# 3284            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3285            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3286            TSC            Zumba - 6-7pm         18:00:00          50
# 3287            TSC            Zumba - 6-7pm         18:00:00          50
# 3288            TSC            Zumba - 6-7pm         18:00:00          50
#
#       Number Booked  Price (INR) BookingEndDateTime
# 0                12        499.0                NaT
# 1                15        499.0                NaT
# 2                14        499.0                NaT
# 3                 9        499.0                NaT
# 4                 7        499.0                NaT
# ...             ...          ...                ...
# 3284              9       1299.0                NaT
# 3285              9       1299.0                NaT
# 3286             16       1299.0                NaT
# 3287             13       1299.0                NaT
# 3288             12       1299.0                NaT
#
# [3271 rows x 7 columns]

# %%
scaler = StandardScaler()
df[['MaxBookees_scaled', 'Number Booked_scaled', 'Price_scaled']] = scaler.fit_transform(
    df[['MaxBookees', 'Number Booked', 'Price (INR)']]
)
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\2915940562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['MaxBookees_scaled', 'Number Booked_scaled', 'Price_scaled']] = scaler.fit_transform(
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\2915940562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['MaxBookees_scaled', 'Number Booked_scaled', 'Price_scaled']] = scaler.fit_transform(
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16156\2915940562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['MaxBookees_scaled', 'Number Booked_scaled', 'Price_scaled']] = scaler.fit_transform(
#      ActivitySiteID      ActivityDescription BookingStartTime  MaxBookees  \
# 0               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 1               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 2               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 3               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 4               HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# ...             ...                      ...              ...         ...
# 3284            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3285            TSC       Zumba  6.30-7.30pm         18:30:00          18
# 3286            TSC            Zumba - 6-7pm         18:00:00          50
# 3287            TSC            Zumba - 6-7pm         18:00:00          50
# 3288            TSC            Zumba - 6-7pm         18:00:00          50
#
#       Number Booked  Price (INR) BookingEndDateTime  MaxBookees_scaled  \
# 0                12        499.0                NaT          -0.477833
# 1                15        499.0                NaT          -0.477833
# 2                14        499.0                NaT          -0.477833
# 3                 9        499.0                NaT          -0.477833
# 4                 7        499.0                NaT          -0.477833
# ...             ...          ...                ...                ...
# 3284              9       1299.0                NaT          -0.940824
# 3285              9       1299.0                NaT          -0.940824
# 3286             16       1299.0                NaT           1.175706
# 3287             13       1299.0                NaT           1.175706
# 3288             12       1299.0                NaT           1.175706
#
#       Number Booked_scaled  Price_scaled
# 0                -0.538786     -1.708124
# 1                -0.223458     -1.708124
# 2                -0.328567     -1.708124
# 3                -0.854114     -1.708124
# 4                -1.064333     -1.708124
# ...                    ...           ...
# 3284             -0.854114     -0.698680
# 3285             -0.854114     -0.698680
# 3286             -0.118348     -0.698680
# 3287             -0.433677     -0.698680
# 3288             -0.538786     -0.698680
#
# [3271 rows x 10 columns]

# %%
quality_report = {
    "Total Rows": len(df),
    "Missing Values": df.isnull().sum().to_dict(),
    "Data Types": df.dtypes.to_dict(),
    "Duplicate Entries Removed": len(df1) + len(df2) - len(df)
}

# Display the cleaned dataset head and quality report
df_cleaned_head = df.head()

# Define the file path first
df_cleaned_path = "cleaned_dynamic_pricing_data.csv"  # Save in current directory

# Now save the file
df.to_csv(df_cleaned_path, index=False)

# Optional display output
print(" Data saved to:", df_cleaned_path)
print("\n Quality Report:\n", quality_report)
df_cleaned_head
# Out:
#  Data saved to: cleaned_dynamic_pricing_data.csv
#
#  Quality Report:
#  {'Total Rows': 3271, 'Missing Values': {'ActivitySiteID': 0, 'ActivityDescription': 0, 'BookingStartTime': 0, 'MaxBookees': 0, 'Number Booked': 0, 'Price (INR)': 0, 'BookingEndDateTime': 3271, 'MaxBookees_scaled': 0, 'Number Booked_scaled': 0, 'Price_scaled': 0}, 'Data Types': {'ActivitySiteID': dtype('O'), 'ActivityDescription': dtype('O'), 'BookingStartTime': dtype('O'), 'MaxBookees': dtype('int64'), 'Number Booked': dtype('int64'), 'Price (INR)': dtype('float64'), 'BookingEndDateTime': dtype('<M8[ns]'), 'MaxBookees_scaled': dtype('float64'), 'Number Booked_scaled': dtype('float64'), 'Price_scaled': dtype('float64')}, 'Duplicate Entries Removed': 18}
#   ActivitySiteID      ActivityDescription BookingStartTime  MaxBookees  \
# 0            HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 1            HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 2            HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 3            HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
# 4            HXP  20-20-20  2.45pm-3.45pm         14:45:00          25
#
#    Number Booked  Price (INR) BookingEndDateTime  MaxBookees_scaled  \
# 0             12        499.0                NaT          -0.477833
# 1             15        499.0                NaT          -0.477833
# 2             14        499.0                NaT          -0.477833
# 3              9        499.0                NaT          -0.477833
# 4              7        499.0                NaT          -0.477833
#
#    Number Booked_scaled  Price_scaled
# 0             -0.538786     -1.708124
# 1             -0.223458     -1.708124
# 2             -0.328567     -1.708124
# 3             -0.854114     -1.708124
# 4             -1.064333     -1.708124
